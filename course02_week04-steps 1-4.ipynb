# %%
import os
execfile(os.path.join(os.environ["SPARK_HOME"], 'python/pyspark/shell.py'))
# Out:
# Welcome to
#       ____              __
#      / __/__  ___ _____/ /__
#     _\ \/ _ \/ _ `/ __/  '_/
#    /__ / .__/\_,_/_/ /_/\_\   version 2.1.1
#       /_/
#
# Using Python version 2.7.12 (default, Nov 19 2016 06:48:10)
# SparkSession available as 'spark'.

# %%
from pyspark.sql import SparkSession
sparkSession = SparkSession.builder.enableHiveSupport().master("local [2]").getOrCreate()

# %%
graphPath = "/data/graphDFSample"

# %%
from pyspark.sql.functions import explode, collect_list, size, col, row_number, sort_array
from pyspark.sql import Window

# %% [markdown]
# <h3>Read the parquet file into DF</h3>

# %%
reversedGraph = sparkSession.read.parquet(graphPath)

# %%
reversedGraph.show(3)
# Out:
# +--------+--------------------+
# |    user|             friends|
# +--------+--------------------+
# |22991438|[20699, 175973, 5...|
# |37586597|[83616, 139192, 1...|
# |56325000|[504270, 645333, ...|
# +--------+--------------------+
# only showing top 3 rows

# %%
reversedGraph.rdd.take(1)
# Out:
# [Row(user=22991438, friends=[20699, 175973, 533235, 584091, 610338, 652317, 840678, 1141589, 1155542, 1239091, 1261113, 1813794, 1815252, 1836438, 1859405, 1860435, 2367768, 2376721, 2460191, 2472708, 2490099, 2492701, 2543851, 2544247, 2554811, 2574091, 2574600, 2615946, 2675180, 2979511, 3039028, 3099044, 3154250, 3183942, 3219940, 3226424, 3227846, 3319312, 3486958, 3717976, 3726009, 3752079, 3759339, 3795687, 3811911, 3823029, 3833714, 3858043, 3874376, 3931989, 3937061, 4064631, 4223807, 4463433, 4479681, 4484282, 4506540, 4558935, 4573610, 4669468, 4709040, 4967644, 4977794, 5047458, 5081445, 5131859, 5133162, 5137845, 5170075, 5183106, 5226216, 5243853, 5247908, 5319361, 5338755, 5510830, 5754472, 5757073, 5807689, 5808282, 5878476, 5899824, 6024877, 6317398, 6345778, 6455669, 6488432, 6535763, 6570921, 6653476, 7103746, 7116529, 7121632, 7155565, 7186124, 7283715, 7497456, 7635033, 7638835, 7641472, 7664866, 7700256, 7727810, 7727974, 7736770, 7747311, 7759953, 7789379, 7973578, 8204083, 8294713, 8350161, 8463384, 8469554, 8492710, 8644690, 8745211, 8784427, 9015105, 9039932, 9095461, 9107084, 9120398, 9123971, 9161252, 9193900, 9203009, 9317330, 9678233, 9745348, 9771555, 9845273, 9846471, 9941235, 10088473, 10151547, 10256979, 10283112, 10335156, 10378632, 10396978, 10405869, 10420650, 10431686, 10500843, 10501405, 10665850, 10679275, 10794609, 10896135, 10923153, 10944250, 11021312, 11023047, 11049259, 11093895, 11160356, 11161448, 11220889, 11312283, 11354267, 11634696, 11650960, 11726547, 11727927, 11760823, 11766799, 11785778, 11798450, 11815638, 11832849, 11941539, 12235818, 12247237, 12267563, 12378179, 12421457, 12429631, 12456000, 12468682, 12577909, 12591951, 12703126, 12765567, 12853166, 12860577, 13016267, 13086454, 13104731, 13132943, 13237805, 13
reversedGraph = reversedGraph.groupBy("friend").agg(collect_list("user").alias("users"))

# %%
reversedGraph.show(3)
# Out:
# +------+--------------------+
# |friend|               users|
# +------+--------------------+
# |   148|[65051219, 146311...|
# |  5518|          [58573511]|
# |  9900|          [36844066]|
# +------+--------------------+
# only showing top 3 rows

# %% [markdown]
# <h3>add user count for each friend</h3>

# %%
reversedGraph = reversedGraph.withColumn("users_size", size("users"))

# %%
reversedGraph.show(3)
# Out:
# +------+--------------------+----------+
# |friend|               users|users_size|
# +------+--------------------+----------+
# |   148|[65051219, 146311...|         4|
# |  5518|          [58573511]|         1|
# |  9900|          [36844066]|         1|
# +------+--------------------+----------+
# only showing top 3 rows

# %%
reversedGraph.rdd.take(3)
# Out:
# [Row(friend=148, users=[65051219, 14631101, 3195315, 14957568], users_size=4),
#  Row(friend=5518, users=[58573511], users_size=1),
#  Row(friend=9900, users=[36844066], users_size=1)]

# %% [markdown]
# <h3>Step 4. Sort the elements in the column “users” by the function sort_array</h3>

# %%
reversedGraph = reversedGraph.select(reversedGraph.friend, sort_array(reversedGraph.users), "users_size")

# %%
reversedGraph.show(3)
# Out:
# +------+-----------------------+----------+
# |friend|sort_array(users, true)|users_size|
# +------+-----------------------+----------+
# |   148|   [3195315, 1463110...|         4|
# |  5518|             [58573511]|         1|
# |  9900|             [36844066]|         1|
# +------+-----------------------+----------+
# only showing top 3 rows

# %%
from pyspark.sql.functions import explode, collect_list, size, col, row_number
from pyspark.sql import Window

reversedGraph = sparkSession.read.parquet(graphPath) \
    .withColumn("friend", explode('friends')) \
    .groupBy("friend") \
    .agg(collect_list("user").alias("users")) \
    .withColumn("users_size", size("users")) \

# %%
reversedGraph.printSchema()
# Out:
# root
#  |-- user: integer (nullable = true)
#  |-- friends: array (nullable = true)
#  |    |-- element: integer (containsNull = true)

# %%
window = Window.orderBy(col("users_size").desc())
    
top50 = reversedGraph.withColumn("row_number", row_number().over(window)) \
            .filter(col("row_number") < 50) \
            .select(col("friend"), col("users_size")) \
            .orderBy(col("users_size").desc()) \
            .collect()

# %%
for val in top50:
    print '%s %s' % val
# Out:
# 9606655 244
# 62922315 241
# 1288836 240
# 36402159 239
# 36079654 239
# 40342046 235
# 24319760 234
# 34854364 234
# 45353567 233
# 28229916 231
# 16364918 230
# 52511791 229
# 549319 227
# 5137947 227
# 65079230 227
# 17636074 226
# 49067109 225
# 53106903 225
# 6570168 223
# 44621704 223
# 34850500 223
# 27338193 222
# 32810368 222
# 25606717 222
# 34201873 220
# 6147442 219
# 62386165 219
# 45239367 219
# 32821462 218
# 30234171 218
# 63649194 217
# 53826156 217
# 13813472 217
# 26158314 217
# 17679500 217
# 14394422 216
# 7153815 216
# 13062446 216
# 36039499 216
# 64373911 216
# 12890141 215
# 20291955 215
# 36757249 214
# 64856469 214
# 40043869 213
# 34071175 212
# 11768267 211
# 38750752 211
# 3295906 211
